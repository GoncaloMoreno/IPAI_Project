# %% [markdown]
# https://archive.eso.org/eso/eso_archive_main.html
#
# RA: 217.42894   DEC: -62.67949
#
# 00 10 00

# %%
import pandas as pd

# %%
vlt_pd = pd.read_csv('vltqueries.csv')

# %%
vlt_pd
# Out:
#                OBJECT          RA        DEC     Program_ID Instrument  \
# 0              OBJECT  217.252125 -62.695083  299.C-5022(A)      HAWKI
# 1              OBJECT  217.252375 -62.695167  299.C-5022(A)      HAWKI
# 2              OBJECT  217.252375 -62.695167  299.C-5022(A)      HAWKI
# 3              OBJECT  217.252750 -62.695222  299.C-5022(A)      HAWKI
# 4              OBJECT  217.252833 -62.695222   60.A-9800(L)      HAWKI
# ...               ...         ...        ...            ...        ...
# 5878        HEAR_SPEC  217.435000 -62.679639   71.C-0026(A)  EFOSC/1.8
# 5879          V645CEN  217.435000 -62.679667   71.C-0026(A)  EFOSC/1.8
# 5880  ESPRI_1429-6240  217.436458 -62.697833  077.A-9009(A)      FEROS
# 5881  ESPRI_1429-6240  217.439042 -62.698194  077.A-9009(A)      FEROS
# 5882              SKY  217.448875 -62.670639  087.C-0423(A)     CRIRES
#
#          Category         Type      Mode                     Dataset ID  \
# ...
